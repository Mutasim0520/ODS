# %%
import numpy as np
from numpy import genfromtxt
import matplotlib.pyplot as plt
from datetime import datetime
from scipy.stats import linregress
from numpy import loadtxt
from scipy import linalg

# %%
data = np.loadtxt("dax_data.txt", comments="#", delimiter="\n")

def create_polynomial_data_matrix(polynomial):
    data_matrix = np.empty((0,(polynomial)),dtype=float)
    i=0
    while i<len(data):
        j=0
        temp_pol = polynomial
        coeffecients = np.empty(0,dtype=float)
        while j<temp_pol:
            coeffecients = np.append(coeffecients,np.array([(i)**(j)]))
            j += 1
        coeffecients = np.sort(coeffecients)[::-1]
        data_matrix = np.append(data_matrix,[np.array(coeffecients)],axis=0)
        i += 1
        
    return data_matrix

# %%
AP3 = create_polynomial_data_matrix(10)

AP3T = AP3.transpose()


AP3T_dot_AP3 = np.dot(AP3T,AP3)

#det_AP3T_dot_AP3 = linalg.det(AP3T_dot_AP3)
#print(det_AP3T_dot_AP3)

inv_AP3T_dot_AP3 = np.linalg.inv(AP3T_dot_AP3)
# print(AP3T_dot_AP3.shape)
# print(np.dot(AP3T,z3).shape)

# xp3 = np.dot(inv_AP3T_dot_AP3,np.dot(AP3T,data))
print(AP3[::-1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-d72feeed9cb8> in <module>
#       6 AP3T_dot_AP3 = np.dot(AP3T,AP3)
#       7
# ----> 8 det_AP3T_dot_AP3 = linalg.det(AP3T_dot_AP3)
#       9 #print(det_AP3T_dot_AP3)
#      10
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\linalg\basic.py in det(a, overwrite_a, check_finite)
#    1032
#    1033     """
# -> 1034     a1 = _asarray_validated(a, check_finite=check_finite)
#    1035     if len(a1.shape) != 2 or a1.shape[0] != a1.shape[1]:
#    1036         raise ValueError('expected square matrix')
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\_lib\_util.py in _asarray_validated(a, check_finite, sparse_ok, objects_ok, mask_ok, as_inexact)
#     247     if not objects_ok:
#     248         if a.dtype is np.dtype('O'):
# --> 249             raise ValueError('object arrays are not supported')
#     250     if as_inexact:
#     251         if not np.issubdtype(a.dtype, np.inexact):
#
# ValueError: object arrays are not supported

# %%
def p_regression(dep_var):
    approximate_output_matrix = np.empty(0)
    dep_var = dep_var[::-1]
    i=0;
    while i<len(data):
        j=0
        result = 0
        while j<len(dep_var):
            result = result+(dep_var[j]*(i**j))
            j += 1
        approximate_output_matrix = np.append(approximate_output_matrix,[result],axis=0)
        i += 1
    return approximate_output_matrix
pr3 = p_regression(xp3)



fig = plt.figure(figsize = (10,10))
plt.plot(pr3)

plt.xlabel('Days after 1st march',fontsize=8)
plt.ylabel('Cumulative death',fontsize=8)
plt.show()

fig = plt.figure(figsize = (10,10))
plt.plot(data)
plt.xlabel('Days after 1st march',fontsize=8)
plt.ylabel('Cumulative death',fontsize=8)
plt.show()

# %%
#SVD
A = create_polynomial_data_matrix(5)
SVD = np.linalg.svd(A, full_matrices=True)

U = SVD[0]
S = SVD[1]
Vt = SVD[2]
# print("Shape of A",A.shape, "Shape of U",U.shape, "Shape of S",S.shape, "Shape of V",Vt.shape)
z_hat = np.dot(U.transpose(),data)
print(z_hat[0:5])

def compute_xHat():
    xHat = np.empty(0,dtype='float')
    i = 0
    while i<len(S):
        xiHat = z_hat[i]/S[i]
        xHat = np.append(xHat,np.array([xiHat]),axis=0)
        i += 1
    return xHat

xHat = compute_xHat()

fig = plt.figure(figsize = (10,10))
x_min = p_regression(np.dot(Vt,xHat))
fig = plt.figure(figsize = (10,10))
plt.plot(x_min)

plt.xlabel('Days ',fontsize=8)
plt.ylabel('Dax',fontsize=8)
plt.show()
print(np.dot(Vt,xHat))
# Out:
# [-552071.78074667  308428.8050778   165259.27595596  133345.76339634
#   -68266.79515694]
# [-1.13772115e-10  1.76959612e-06  6.19115539e-03  8.98681087e-01
#   4.10117378e+03]

# %%
z = np.poly1d(data, (np.arange(0,len(data),1)), 10)
p = np.poly1d(np.polyfit(x, y, 3))


plt.plot(z)
fig = plt.figure(figsize = (10,10))
plt.plot(z)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-b5e9f7253ac6> in <module>
# ----> 1 z = np.poly1d(data, (np.arange(0,len(data),1)), 10)
#       2 p = np.poly1d(np.polyfit(x, y, 3))
#       3
#       4
#       5 plt.plot(z)
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\polynomial.py in __init__(self, c_or_r, r, variable)
#    1165                 self._variable = variable
#    1166             return
# -> 1167         if r:
#    1168             c_or_r = poly(c_or_r)
#    1169         c_or_r = atleast_1d(c_or_r)
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
